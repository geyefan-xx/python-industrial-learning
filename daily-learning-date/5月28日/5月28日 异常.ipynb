# %% [raw]
# SyntaxError：语法异常
# ZeroDivisionEror
# TypeErrorStopIteration

# %%
#try-exception
try:
    1/0
except ZeroDivisionError:
    print("出错了")
# Out:
# 出错了

# %%
try:
    1/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    1/0
    114+"python"
except (ZeroDivisionError,ValueError,TypeError):
    pass

# %%
try:
    1/0
    114+"python"
except ZeroDivisionError:
    print("零不能为除数")
except ValueError:
    print("值错误")
except TypeError:
    print("类型错误")
# Out:
# 零不能为除数

# %%
try:
    1/0
except (ZeroDivisionError,ValueError,TypeError) as e:
    print(f"发现错误{e}")
else:
    print("未发现异常")
# Out:
# 发现错误division by zero

# %%
try:
    1/2
except (ZeroDivisionError,ValueError,TypeError) as e:
    print(f"发现错误{e}")
else:
    print("未发现异常")
# Out:
# 未发现异常

# %%
try:
    1/0
except (ZeroDivisionError,ValueError,TypeError) as e:
    print(f"发现错误{e}")
else:
    print("未发现异常")
finally:
    print("执行完毕")
# Out:
# 发现错误division by zero
# 执行完毕

# %%
try:
    f=open("test.txt","w")
    f.write("python很有趣")
except:
    print("出错了")
finally:
    f.close()

# %%
try:
    try:
        114+"python"
    except:
        print("内部异常")
    1/0
except:
    print("外部异常")
finally:
     print("执行完毕")
# Out:
# 内部异常
# 外部异常
# 执行完毕

# %%
#raise
raise ValueError("值不正确")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 #raise
# ----> 2 raise ValueError("值不正确")
#
# ValueError: 值不正确

# %%
raise ValueError("值不正确") from ZeroDivisionError
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ZeroDivisionError:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 raise ValueError("值不正确") from ZeroDivisionError
#
# ValueError: 值不正确

# %%
s="python"
assert s!="python"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 s="python"
# ----> 2 assert s!="python"
#
# AssertionError:
